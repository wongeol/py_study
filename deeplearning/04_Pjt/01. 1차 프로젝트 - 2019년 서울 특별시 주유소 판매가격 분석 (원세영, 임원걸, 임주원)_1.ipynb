# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# # 1. 데이터 불러오기

# %%
# 상반기 주유소 판매 데이터 불러오기

first = pd.read_csv('../data/2019년 상반기 주유소 판매가격.csv', encoding='cp949')
first
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 90585  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190626  GS칼텍스   셀프
# 90586  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190627  GS칼텍스   셀프
# 90587  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190628  GS칼텍스   셀프
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# 0       1673  1465  1365     0
# 1       1673  1465  1365     0
# 2       1673  1465  1365     0
# 3       1673  1465  1365     0
# 4       1673  1465  1365     0
# ...      ...   ...   ...   ...
# 90585      0  1529  1389     0
# 90586      0  1529  1389     0
# 90587      0  1529  1389     0
# 90588      0  1529  1389     0
# 90589      0  1529  1389     0
#
# [90590 rows x 11 columns]

# %%
# 하반기 주유소 판매 데이터 불러오기
second = pd.read_csv('../data/2019년 하반기 주유소 판매가격.csv', encoding='cp949')
second
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# 0       1777  1577  1477     0
# 1       1777  1577  1477     0
# 2       1777  1577  1477     0
# 3       1777  1577  1477     0
# 4       1777  1577  1477     0
# ...      ...   ...   ...   ...
# 91119      0  1540  1389  1100
# 91120      0  1540  1389  1100
# 91121      0  1540  1389  1100
# 91122      0  1540  1389  1100
# 91123      0  1540  1389  1100
#
# [91124 rows x 11 columns]

# %%
# 상반기 판매가격 데이터 프레임 결측치 DataFrame조회
first.isnull()
# Out:
#           번호     지역     상호     주소     기간     상표   셀프여부  고급휘발유    휘발유     경유  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 90585  False  False  False  False  False  False  False  False  False  False
# 90586  False  False  False  False  False  False  False  False  False  False
# 90587  False  False  False  False  False  False  False  False  False  False
# 90588  False  False  False  False  False  False  False  False  False  False
# 90589  False  False  False  False  False  False  False  False  False  False
#
#         실내등유
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 90585  False
# 90586  False
# 90587  False
# 90588  False
# 90589  False
#
# [90590 rows x 11 columns]

# %%
# 상반기 판매가격 데이터 프레임 결측치 합 조회
first.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %%
# 하반기 판매가격 데이터 프레임 결측치 DataFrame조회
second.isnull()
# Out:
#           번호     지역     상호     주소     기간     상표   셀프여부  고급휘발유    휘발유     경유  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 91119  False  False  False  False  False  False  False  False  False  False
# 91120  False  False  False  False  False  False  False  False  False  False
# 91121  False  False  False  False  False  False  False  False  False  False
# 91122  False  False  False  False  False  False  False  False  False  False
# 91123  False  False  False  False  False  False  False  False  False  False
#
#         실내등유
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 91119  False
# 91120  False
# 91121  False
# 91122  False
# 91123  False
#
# [91124 rows x 11 columns]

# %%
# 하반기 판매가격 데이터 프레임 결측치 합 조회
second.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %% [markdown]
# # 2. 데이터 결합

# %%
# 상반기와 하반기 데이터를 상하로 결합
df = pd.concat([first,second],keys=['상반기','하반기'], ignore_index=True) # ignore_index=True : 인덱스 초기화하고 순서별로
df
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유
# 0        1673  1465  1365     0
# 1        1673  1465  1365     0
# 2        1673  1465  1365     0
# 3        1673  1465  1365     0
# 4        1673  1465  1365     0
# ...       ...   ...   ...   ...
# 181709      0  1540  1389  1100
# 181710      0  1540  1389  1100
# 181711      0  1540  1389  1100
# 181712      0  1540  1389  1100
# 181713      0  1540  1389  1100
#
# [181714 rows x 11 columns]

# %% [markdown]
# # 3. 데이터 가공 및 분석

# %%
# 데이터 프레임 정보 조회
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181714 entries, 0 to 181713
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  int64
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 15.3+ MB

# %%
# 상표 컬럼의 고유값 조회
df['상표'].unique()
# Out:
# array(['SK에너지', 'GS칼텍스', 'S-OIL', '현대오일뱅크', '알뜰주유소', 'NH-OIL', '알뜰(ex)',
#        '자가상표'], dtype=object)

# %%
# 지역 컬럼의 고유값 조회
df['지역'].unique()
# Out:
# array(['서울 강남구', '서울 강동구', '서울 강북구', '서울 강서구', '서울 관악구', '서울 광진구',
#        '서울 구로구', '서울 금천구', '서울 노원구', '서울 도봉구', '서울 동대문구', '서울 동작구',
#        '서울 마포구', '서울 서대문구', '서울 서초구', '서울 성동구', '서울 성북구', '서울 송파구',
#        '서울 양천구', '서울 영등포구', '서울 용산구', '서울 은평구', '서울 종로구', '서울 중구',
#        '서울 중랑구'], dtype=object)

# %%
# 지역 컬럼의 값을 이용하여 시와 구를 분리
name_split = df['지역'].str.split(" ")
df['시'] = name_split.str.get(0)
df['구'] = name_split.str.get(1)
df
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유   시    구
# 0        1673  1465  1365     0  서울  강남구
# 1        1673  1465  1365     0  서울  강남구
# 2        1673  1465  1365     0  서울  강남구
# 3        1673  1465  1365     0  서울  강남구
# 4        1673  1465  1365     0  서울  강남구
# ...       ...   ...   ...   ...  ..  ...
# 181709      0  1540  1389  1100  서울  중랑구
# 181710      0  1540  1389  1100  서울  중랑구
# 181711      0  1540  1389  1100  서울  중랑구
# 181712      0  1540  1389  1100  서울  중랑구
# 181713      0  1540  1389  1100  서울  중랑구
#
# [181714 rows x 13 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 시 컬럼의 서울을 서울특별시로 변환
df.loc[df['시']=='서울','시'] = '서울특별시'
df
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유      시    구
# 0        1673  1465  1365     0  서울특별시  강남구
# 1        1673  1465  1365     0  서울특별시  강남구
# 2        1673  1465  1365     0  서울특별시  강남구
# 3        1673  1465  1365     0  서울특별시  강남구
# 4        1673  1465  1365     0  서울특별시  강남구
# ...       ...   ...   ...   ...    ...  ...
# 181709      0  1540  1389  1100  서울특별시  중랑구
# 181710      0  1540  1389  1100  서울특별시  중랑구
# 181711      0  1540  1389  1100  서울특별시  중랑구
# 181712      0  1540  1389  1100  서울특별시  중랑구
# 181713      0  1540  1389  1100  서울특별시  중랑구
#
# [181714 rows x 13 columns]

# %%
# 기간 컬럼을 datetime 형식으로 변경
df['기간']= pd.to_datetime(df['기간'],format='%Y%m%d')
df
# Out:
#               번호      지역             상호              주소         기간     상표  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지
# ...          ...     ...            ...             ...        ...    ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유      시    구
# 0        셀프   1673  1465  1365     0  서울특별시  강남구
# 1        셀프   1673  1465  1365     0  서울특별시  강남구
# 2        셀프   1673  1465  1365     0  서울특별시  강남구
# 3        셀프   1673  1465  1365     0  서울특별시  강남구
# 4        셀프   1673  1465  1365     0  서울특별시  강남구
# ...     ...    ...   ...   ...   ...    ...  ...
# 181709   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181710   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181711   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181712   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181713   셀프      0  1540  1389  1100  서울특별시  중랑구
#
# [181714 rows x 13 columns]

# %%
# 변경된 데이터 타입 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181714 entries, 0 to 181713
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  datetime64[ns]
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
#  11  시       181714 non-null  object
#  12  구       181714 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 18.0+ MB

# %%
# 기간 컬럼에서 dt 타입을 이용하여 년, 월, 일, 요일 컬럼 생성
# (참고) https://m.blog.naver.com/PostView.nhn?blogId=wideeyed&logNo=221603462366&proxyReferer=https:%2F%2Fwww.google.com%2F 
df['년'] = df['기간'].dt.year
df['월'] = df['기간'].dt.month
df['일'] = df['기간'].dt.day
df['요일'] = df['기간'].dt.day_name()
df
# Out:
#               번호      지역             상호              주소         기간     상표  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지
# ...          ...     ...            ...             ...        ...    ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유      시    구     년   월   일         요일
# 0        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   1    Tuesday
# 1        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   2  Wednesday
# 2        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   3   Thursday
# 3        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   4     Friday
# 4        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   5   Saturday
# ...     ...    ...   ...   ...   ...    ...  ...   ...  ..  ..        ...
# 181709   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  27     Friday
# 181710   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  28   Saturday
# 181711   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  29     Sunday
# 181712   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  30     Monday
# 181713   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  31    Tuesday
#
# [181714 rows x 17 columns]

# %%
# 휘발유 가격이 비싼 5개 판매가격을 출력하세요.
df.sort_values(by=['휘발유'], ascending=False).head()
# Out:
#               번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 177210  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-24  SK에너지   일반   2649
# 177216  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 177217  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 177211  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 177212  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
#
#          휘발유    경유  실내등유      시   구     년   월   일         요일
# 177210  2356  2196     0  서울특별시  중구  2019   9  24    Tuesday
# 177216  2356  2196     0  서울특별시  중구  2019   9  30     Monday
# 177217  2356  2196     0  서울특별시  중구  2019  10   1    Tuesday
# 177211  2356  2196     0  서울특별시  중구  2019   9  25  Wednesday
# 177212  2356  2196     0  서울특별시  중구  2019   9  26   Thursday

# %%
# 휘발유 가격이 저렴한 5개 판매가격을 출력하세요. (단 휘발유가 0원인 데이터는 제외)
df.sort_values(by=['휘발유']).loc[df['휘발유']>0].head()
# Out:
#              번호      지역                   상호                    주소         기간  \
# 13148  A0033328  서울 강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30 2019-02-07
# 82476  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-02-01
# 82475  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-31
# 82474  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-30
# 83002  A0000690  서울 은평구    지에스칼텍스(주)수색뉴타운주유소  서울 은평구 수색로 350 (수색동) 2019-01-30
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유      시    구     년  월   일         요일
# 13148  SK에너지   셀프   1788  1255  1155     0  서울특별시  강서구  2019  2   7   Thursday
# 82476  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  2   1     Friday
# 82475  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  1  31   Thursday
# 82474  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  1  30  Wednesday
# 83002  GS칼텍스   셀프      0  1265  1165     0  서울특별시  은평구  2019  1  30  Wednesday

# %% [markdown]
# 그래프 10개
# 이런 해당 주제에 잘 부합한 그래프로 보여주기
#
# 1. 휘발유 가격이 어떻게 분포되어있나? - 지역별, 상표별 - lmplot
#
# 5. 셀프 주유소가 일반 주유소보다 싼가?
#
#
# lmplot
#
# 상표별 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 상표 종류
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 상표와 낮은 상표
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 상표와 낮은 상표
#
# 지역별(구) 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 지역(구)
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 지역과 낮은 지역
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 지역와 낮은 지역

# %%
import seaborn as sns

# %% [markdown]
# ## 지역별, 상표별 휘발유,경유 가격이 어떻게 분포되어있는가?

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='상표', y='휘발유', data=df)
# plt.yticks(step=100)
plt.xlabel('상표')
plt.ylabel('휘발유')

plt.title('상표별 휘발유 가격이 어떻게 분포되어있는가?')
plt.grid()

# plt.axis([,,1000, 2000]) # 50,150 : x 영역 | 0, 0.03 : y 영역
plt.ylim([1200 ,2000])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='상표', y='경유', data=df)

plt.xlabel('상표')
plt.ylabel('경유')

plt.title('상표별 경유 가격이 어떻게 분포되어있는가?')
plt.grid()

plt.ylim([1200 ,2000])
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.boxplot(x='지역', y='휘발유', data=df)

plt.xlabel('지역')
plt.ylabel('휘발유')

plt.title('지역별 휘발유 가격이 어떻게 분포되어있는가?')
plt.grid()

plt.ylim([1200 ,2500])
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.boxplot(x='지역', y='경유', data=df)

plt.xlabel('지역')
plt.ylabel('경유')

plt.title('지역별 경유 가격이 어떻게 분포되어있는가?')
plt.grid()

plt.ylim([1200 ,2200])
plt.show()

# %%
df.head(3)
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday

# %% [markdown]
# ## 셀프 주유소가 일반 주유소보다 싼가?

# %%
df1 = df[['상표','셀프여부','휘발유']]
df1.pivot_table(index='상표', values='휘발유', columns='셀프여부') #   aggfunc='mean'
# Out:
# 셀프여부             셀프           일반
# 상표
# GS칼텍스   1481.410074  1610.060123
# NH-OIL          NaN  1449.088889
# S-OIL   1481.437428  1579.451162
# SK에너지   1504.853863  1690.377765
# 알뜰(ex)  1431.347945          NaN
# 알뜰주유소   1434.726027  1455.372511
# 자가상표    1494.409449  1491.740351
# 현대오일뱅크  1483.546767  1534.254225

# %%
sns.catplot( data=df1, kind="bar",
    x="상표", y="휘발유", hue="셀프여부",ci="sd",height=6)
plt.show()

# %% [markdown]
# ## 상표별 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 상표 종류
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 상표와 낮은 상표
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 상표와 낮은 상표

# %%
df.head(3)
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday

# %%
# 사용할 데이터
df[['기간','상표','고급휘발유','휘발유','경유', '셀프여부']].head()
# Out:
#           기간     상표  고급휘발유   휘발유    경유 셀프여부
# 0 2019-01-01  SK에너지   1673  1465  1365   셀프
# 1 2019-01-02  SK에너지   1673  1465  1365   셀프
# 2 2019-01-03  SK에너지   1673  1465  1365   셀프
# 3 2019-01-04  SK에너지   1673  1465  1365   셀프
# 4 2019-01-05  SK에너지   1673  1465  1365   셀프

# %%
d1 = df.pivot_table(values=['휘발유'], index=['기간'], columns=['상표']) #   aggfunc='mean'
d1.head(1)
# Out:
#                     휘발유                                                     \
# 상표                GS칼텍스  NH-OIL    S-OIL        SK에너지  알뜰(ex)        알뜰주유소
# 기간
# 2019-01-01  1485.786765  1399.0  1453.36  1540.519802  1299.0  1355.181818
#
#
# 상표                 자가상표       현대오일뱅크
# 기간
# 2019-01-01  1406.666667  1449.935897

# %%
# dates = df['기간']
# values = df['휘발유']
data = pd.DataFrame(values, dates, columns=["GS칼텍스", "S-OIL"])
data = data.rolling(7).mean()


sns.lineplot(data=data,palette="tab10", linewidth=2.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-0fb3d191d248> in <module>
#       7 # sns.lineplot(data=data,palette="tab10", linewidth=2.5)
#       8 # sns.lineplot?
# ----> 9 sns.lineplot(data=d1,x='기간',y='휘발유')
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     683
#     684     variables = _LinePlotter.get_semantics(locals())
# --> 685     p = _LinePlotter(
#     686         data=data, variables=variables,
#     687         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     924         # Construct a tidy plot DataFrame. This will convert a number of
#     925         # types automatically, aligning on index in case of pandas objects
# --> 926         plot_data = pd.DataFrame(plot_data)
#     927
#     928         # Reduce the variables dictionary to fields with valid data
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      91     axes = [columns, index]
#      92
# ---> 93     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      94
#      95
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1695         return mgr
#    1696     except ValueError as e:
# -> 1697         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1698
#    1699
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1691     try:
#    1692         blocks = form_blocks(arrays, names, axes)
# -> 1693         mgr = BlockManager(blocks, axes)
#    1694         mgr._consolidate_inplace()
#    1695         return mgr
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     147
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#     151         # Populate known_consolidate, blknos, and blklocs lazily
#
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     327         for block in self.blocks:
#     328             if block.shape[1:] != mgr_shape[1:]:
# --> 329                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     330         if len(self.items) != tot_items:
#     331             raise AssertionError(
#
# ValueError: Shape of passed values is (8, 2), indices imply (365, 2)

# %%
d2 = df.pivot_table(values='경유', index='상표', columns=['셀프여부','기간'])
d2.head(1)
# Out:
# 셀프여부            셀프                                                    \
# 기간      2019-01-01   2019-01-02   2019-01-03   2019-01-04 2019-01-05
# 상표
# GS칼텍스  1294.229167  1286.916667  1284.520833  1281.770833   1279.375
#
# 셀프여부                                                                ...  \
# 기간      2019-01-06   2019-01-07   2019-01-08 2019-01-09 2019-01-10  ...
# 상표                                                                  ...
# GS칼텍스  1277.895833  1276.770833  1274.333333   1273.125   1269.125  ...
#
# 셀프여부            일반                                                    \
# 기간      2019-12-22   2019-12-23   2019-12-24  2019-12-25  2019-12-26
# 상표
# GS칼텍스  1534.674419  1534.860465  1536.697674  1537.27907  1539.05814
#
# 셀프여부
# 기간      2019-12-27   2019-12-28   2019-12-29   2019-12-30   2019-12-31
# 상표
# GS칼텍스  1538.788235  1540.141176  1539.317647  1539.976471  1540.670588
#
# [1 rows x 730 columns]

# %%
d3 = df.pivot_table(values='고급휘발유', index='상표', columns=['셀프여부','기간'])
d3.head(1)
# Out:
# 셀프여부           셀프                                                            \
# 기간     2019-01-01  2019-01-02 2019-01-03  2019-01-04  2019-01-05 2019-01-06
# 상표
# GS칼텍스  829.791667  828.958333   828.8125  823.854167  821.979167   820.9375
#
# 셀프여부                                               ...           일반  \
# 기간    2019-01-07 2019-01-08 2019-01-09 2019-01-10  ...   2019-12-22
# 상표                                                 ...
# GS칼텍스   820.9375    820.375   818.4375   817.8125  ...  1125.616279
#
# 셀프여부                                                                   \
# 기간      2019-12-23   2019-12-24  2019-12-25   2019-12-26   2019-12-27
# 상표
# GS칼텍스  1126.081395  1102.581395  1104.55814  1105.337209  1118.341176
#
# 셀프여부
# 기간      2019-12-28   2019-12-29   2019-12-30 2019-12-31
# 상표
# GS칼텍스  1118.341176  1118.576471  1118.847059     1119.2
#
# [1 rows x 730 columns]

# %% [markdown]
# 지역별(구) 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 지역(구)
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 지역과 낮은 지역
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 지역와 낮은 지역
