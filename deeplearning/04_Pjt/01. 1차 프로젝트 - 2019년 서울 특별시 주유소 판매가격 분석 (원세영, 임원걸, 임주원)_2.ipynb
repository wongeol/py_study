# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame, Series
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# # 1. 데이터 불러오기

# %%
# 상반기 주유소 판매 데이터 불러오기

first = pd.read_csv('../data/2019년 상반기 주유소 판매가격.csv', encoding='cp949')
first
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 90585  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190626  GS칼텍스   셀프
# 90586  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190627  GS칼텍스   셀프
# 90587  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190628  GS칼텍스   셀프
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# 0       1673  1465  1365     0
# 1       1673  1465  1365     0
# 2       1673  1465  1365     0
# 3       1673  1465  1365     0
# 4       1673  1465  1365     0
# ...      ...   ...   ...   ...
# 90585      0  1529  1389     0
# 90586      0  1529  1389     0
# 90587      0  1529  1389     0
# 90588      0  1529  1389     0
# 90589      0  1529  1389     0
#
# [90590 rows x 11 columns]

# %%
# 하반기 주유소 판매 데이터 불러오기
second = pd.read_csv('../data/2019년 하반기 주유소 판매가격.csv', encoding='cp949')
second
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# 0       1777  1577  1477     0
# 1       1777  1577  1477     0
# 2       1777  1577  1477     0
# 3       1777  1577  1477     0
# 4       1777  1577  1477     0
# ...      ...   ...   ...   ...
# 91119      0  1540  1389  1100
# 91120      0  1540  1389  1100
# 91121      0  1540  1389  1100
# 91122      0  1540  1389  1100
# 91123      0  1540  1389  1100
#
# [91124 rows x 11 columns]

# %%
# 상반기 판매가격 데이터 프레임 결측치 DataFrame조회
first.isnull()
# Out:
#           번호     지역     상호     주소     기간     상표   셀프여부  고급휘발유    휘발유     경유  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 90585  False  False  False  False  False  False  False  False  False  False
# 90586  False  False  False  False  False  False  False  False  False  False
# 90587  False  False  False  False  False  False  False  False  False  False
# 90588  False  False  False  False  False  False  False  False  False  False
# 90589  False  False  False  False  False  False  False  False  False  False
#
#         실내등유
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 90585  False
# 90586  False
# 90587  False
# 90588  False
# 90589  False
#
# [90590 rows x 11 columns]

# %%
# 상반기 판매가격 데이터 프레임 결측치 합 조회
first.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %%
# 하반기 판매가격 데이터 프레임 결측치 DataFrame조회
second.isnull()
# Out:
#           번호     지역     상호     주소     기간     상표   셀프여부  고급휘발유    휘발유     경유  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 91119  False  False  False  False  False  False  False  False  False  False
# 91120  False  False  False  False  False  False  False  False  False  False
# 91121  False  False  False  False  False  False  False  False  False  False
# 91122  False  False  False  False  False  False  False  False  False  False
# 91123  False  False  False  False  False  False  False  False  False  False
#
#         실내등유
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 91119  False
# 91120  False
# 91121  False
# 91122  False
# 91123  False
#
# [91124 rows x 11 columns]

# %%
# 하반기 판매가격 데이터 프레임 결측치 합 조회
second.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %%
# 상반기와 하반기 데이터를 상하로 결합
df = pd.concat([first,second],keys=['상반기','하반기'], ignore_index=True) # ignore_index=True : 인덱스 초기화하고 순서별로
df
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유
# 0        1673  1465  1365     0
# 1        1673  1465  1365     0
# 2        1673  1465  1365     0
# 3        1673  1465  1365     0
# 4        1673  1465  1365     0
# ...       ...   ...   ...   ...
# 181709      0  1540  1389  1100
# 181710      0  1540  1389  1100
# 181711      0  1540  1389  1100
# 181712      0  1540  1389  1100
# 181713      0  1540  1389  1100
#
# [181714 rows x 11 columns]

# %% [markdown]
# # 2. 데이터 결합

# %% [markdown]
# # 3. 데이터 가공 및 분석

# %%
# 데이터 프레임 정보 조회
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181714 entries, 0 to 181713
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  int64
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 15.3+ MB

# %%
# 상표 컬럼의 고유값 조회
df['상표'].unique()
# Out:
# array(['SK에너지', 'GS칼텍스', 'S-OIL', '현대오일뱅크', '알뜰주유소', 'NH-OIL', '알뜰(ex)',
#        '자가상표'], dtype=object)

# %%
# 지역 컬럼의 고유값 조회
df['지역'].unique()
# Out:
# array(['서울 강남구', '서울 강동구', '서울 강북구', '서울 강서구', '서울 관악구', '서울 광진구',
#        '서울 구로구', '서울 금천구', '서울 노원구', '서울 도봉구', '서울 동대문구', '서울 동작구',
#        '서울 마포구', '서울 서대문구', '서울 서초구', '서울 성동구', '서울 성북구', '서울 송파구',
#        '서울 양천구', '서울 영등포구', '서울 용산구', '서울 은평구', '서울 종로구', '서울 중구',
#        '서울 중랑구'], dtype=object)

# %%
# 지역 컬럼의 값을 이용하여 시와 구를 분리
name_split = df['지역'].str.split(" ")
df['시'] = name_split.str.get(0)
df['구'] = name_split.str.get(1)
df
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유   시    구
# 0        1673  1465  1365     0  서울  강남구
# 1        1673  1465  1365     0  서울  강남구
# 2        1673  1465  1365     0  서울  강남구
# 3        1673  1465  1365     0  서울  강남구
# 4        1673  1465  1365     0  서울  강남구
# ...       ...   ...   ...   ...  ..  ...
# 181709      0  1540  1389  1100  서울  중랑구
# 181710      0  1540  1389  1100  서울  중랑구
# 181711      0  1540  1389  1100  서울  중랑구
# 181712      0  1540  1389  1100  서울  중랑구
# 181713      0  1540  1389  1100  서울  중랑구
#
# [181714 rows x 13 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 시 컬럼의 서울을 서울특별시로 변환
df.loc[df['시']=='서울','시'] = '서울특별시'
df
# Out:
#               번호      지역             상호              주소        기간     상표 셀프여부  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...          ...     ...            ...             ...       ...    ...  ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#         고급휘발유   휘발유    경유  실내등유      시    구
# 0        1673  1465  1365     0  서울특별시  강남구
# 1        1673  1465  1365     0  서울특별시  강남구
# 2        1673  1465  1365     0  서울특별시  강남구
# 3        1673  1465  1365     0  서울특별시  강남구
# 4        1673  1465  1365     0  서울특별시  강남구
# ...       ...   ...   ...   ...    ...  ...
# 181709      0  1540  1389  1100  서울특별시  중랑구
# 181710      0  1540  1389  1100  서울특별시  중랑구
# 181711      0  1540  1389  1100  서울특별시  중랑구
# 181712      0  1540  1389  1100  서울특별시  중랑구
# 181713      0  1540  1389  1100  서울특별시  중랑구
#
# [181714 rows x 13 columns]

# %%
# 기간 컬럼을 datetime 형식으로 변경
df['기간']= pd.to_datetime(df['기간'],format='%Y%m%d')
df
# Out:
#               번호      지역             상호              주소         기간     상표  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지
# ...          ...     ...            ...             ...        ...    ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유      시    구
# 0        셀프   1673  1465  1365     0  서울특별시  강남구
# 1        셀프   1673  1465  1365     0  서울특별시  강남구
# 2        셀프   1673  1465  1365     0  서울특별시  강남구
# 3        셀프   1673  1465  1365     0  서울특별시  강남구
# 4        셀프   1673  1465  1365     0  서울특별시  강남구
# ...     ...    ...   ...   ...   ...    ...  ...
# 181709   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181710   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181711   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181712   셀프      0  1540  1389  1100  서울특별시  중랑구
# 181713   셀프      0  1540  1389  1100  서울특별시  중랑구
#
# [181714 rows x 13 columns]

# %%
# 변경된 데이터 타입 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181714 entries, 0 to 181713
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  datetime64[ns]
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
#  11  시       181714 non-null  object
#  12  구       181714 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 18.0+ MB

# %%
# 기간 컬럼에서 dt 타입을 이용하여 년, 월, 일, 요일 컬럼 생성
# (참고) https://m.blog.naver.com/PostView.nhn?blogId=wideeyed&logNo=221603462366&proxyReferer=https:%2F%2Fwww.google.com%2F 
df['년'] = df['기간'].dt.year
df['월'] = df['기간'].dt.month
df['일'] = df['기간'].dt.day
df['요일'] = df['기간'].dt.day_name()
df
# Out:
#               번호      지역             상호              주소         기간     상표  \
# 0       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지
# 1       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지
# 2       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지
# 3       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지
# 4       A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지
# ...          ...     ...            ...             ...        ...    ...
# 181709  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스
# 181710  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스
# 181711  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스
# 181712  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스
# 181713  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유      시    구     년   월   일         요일
# 0        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   1    Tuesday
# 1        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   2  Wednesday
# 2        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   3   Thursday
# 3        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   4     Friday
# 4        셀프   1673  1465  1365     0  서울특별시  강남구  2019   1   5   Saturday
# ...     ...    ...   ...   ...   ...    ...  ...   ...  ..  ..        ...
# 181709   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  27     Friday
# 181710   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  28   Saturday
# 181711   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  29     Sunday
# 181712   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  30     Monday
# 181713   셀프      0  1540  1389  1100  서울특별시  중랑구  2019  12  31    Tuesday
#
# [181714 rows x 17 columns]

# %%
# 휘발유 가격이 비싼 5개 판매가격을 출력하세요.
df.sort_values(by=['휘발유'], ascending=False).head()
# Out:
#               번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 177210  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-24  SK에너지   일반   2649
# 177216  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 177217  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 177211  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 177212  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
#
#          휘발유    경유  실내등유      시   구     년   월   일         요일
# 177210  2356  2196     0  서울특별시  중구  2019   9  24    Tuesday
# 177216  2356  2196     0  서울특별시  중구  2019   9  30     Monday
# 177217  2356  2196     0  서울특별시  중구  2019  10   1    Tuesday
# 177211  2356  2196     0  서울특별시  중구  2019   9  25  Wednesday
# 177212  2356  2196     0  서울특별시  중구  2019   9  26   Thursday

# %%
# 휘발유 가격이 저렴한 5개 판매가격을 출력하세요. (단 휘발유가 0원인 데이터는 제외)
df.sort_values(by=['휘발유']).loc[df['휘발유']>0].head()
# Out:
#              번호      지역                   상호                    주소         기간  \
# 13148  A0033328  서울 강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30 2019-02-07
# 82476  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-02-01
# 82475  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-31
# 82474  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-30
# 83002  A0000690  서울 은평구    지에스칼텍스(주)수색뉴타운주유소  서울 은평구 수색로 350 (수색동) 2019-01-30
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유      시    구     년  월   일         요일
# 13148  SK에너지   셀프   1788  1255  1155     0  서울특별시  강서구  2019  2   7   Thursday
# 82476  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  2   1     Friday
# 82475  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  1  31   Thursday
# 82474  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  1  30  Wednesday
# 83002  GS칼텍스   셀프      0  1265  1165     0  서울특별시  은평구  2019  1  30  Wednesday

# %% [markdown]
# 그래프 10개
# 이런 해당 주제에 잘 부합한 그래프로 보여주기
#
# 1. 휘발유 가격이 어떻게 분포되어있나? - 지역별, 상표별 - lmplot
#
# 5. 셀프 주유소가 일반 주유소보다 싼가?
#
#
# lmplot
#
# 상표별 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 상표 종류
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 상표와 낮은 상표
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 상표와 낮은 상표
#
# 지역별(구) 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 지역(구)
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 지역과 낮은 지역
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 지역와 낮은 지역

# %%
import seaborn as sns

# %% [markdown]
# ## 지역별, 상표별 휘발유,경유 가격이 어떻게 분포되어있는가?

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='상표', y='휘발유', data=df)
# plt.yticks(step=100)
plt.xlabel('상표')
plt.ylabel('휘발유')

plt.title('상표별 휘발유 가격이 어떻게 분포되어있는가?')
plt.grid()

# plt.axis([,,1000, 2000]) # 50,150 : x 영역 | 0, 0.03 : y 영역
plt.ylim([1200 ,2000])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='상표', y='경유', data=df)

plt.xlabel('상표')
plt.ylabel('경유')

plt.title('상표별 경유 가격이 어떻게 분포되어있는가?')
plt.grid()

plt.ylim([1200 ,2000])
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.boxplot(x='지역', y='휘발유', data=df)

plt.xlabel('지역')
plt.ylabel('휘발유')

plt.title('지역별 휘발유 가격이 어떻게 분포되어있는가?')
plt.grid()

plt.ylim([1200 ,2500])
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.boxplot(x='지역', y='경유', data=df)

plt.xlabel('지역')
plt.ylabel('경유')

plt.title('지역별 경유 가격이 어떻게 분포되어있는가?')
plt.grid()

plt.ylim([1200 ,2200])
plt.show()

# %%
df.head(3)
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday

# %% [markdown]
# ## 셀프 주유소가 일반 주유소보다 싼가?

# %%
df1 = df[['상표','셀프여부','휘발유']]
df1.pivot_table(index='상표', values='휘발유', columns='셀프여부') #   aggfunc='mean'
# Out:
# 셀프여부             셀프           일반
# 상표
# GS칼텍스   1481.410074  1610.060123
# NH-OIL          NaN  1449.088889
# S-OIL   1481.437428  1579.451162
# SK에너지   1504.853863  1690.377765
# 알뜰(ex)  1431.347945          NaN
# 알뜰주유소   1434.726027  1455.372511
# 자가상표    1494.409449  1491.740351
# 현대오일뱅크  1483.546767  1534.254225

# %%
sns.catplot( data=df1, kind="bar",
    x="상표", y="휘발유", hue="셀프여부",ci="sd",height=6)
plt.show()

# %% [markdown]
# ## 요일별 휘발유 가격

# %%
df.head(1)
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일       요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1  Tuesday

# %%
days= df[['요일','휘발유']]
days.rename(columns={'요일':'day','휘발유':'gasoline'}, inplace = True)
days
# Out:
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#               day  gasoline
# 0         Tuesday      1465
# 1       Wednesday      1465
# 2        Thursday      1465
# 3          Friday      1465
# 4        Saturday      1465
# ...           ...       ...
# 181709     Friday      1540
# 181710   Saturday      1540
# 181711     Sunday      1540
# 181712     Monday      1540
# 181713    Tuesday      1540
#
# [181714 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))
sns.set_style(style="whitegrid")


sns.violinplot(data=days, x="day", y="gasoline", linewidth=1)
plt.show()

# %% [markdown]
# ## 기간별 경유, 휘발유, 고급휘발유 평균 가격 변화

# %%
df.head(3)
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday

# %%
df1 = df[['기간', '고급휘발유', '휘발유', '경유']]
df1.rename(columns={'기간':'day','고급휘발유':'high-gasoline','휘발유':'gasoline', '경유':'diesel'}, inplace = True)
df1
# Out:
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#               day  high-gasoline  gasoline  diesel
# 0      2019-01-01           1673      1465    1365
# 1      2019-01-02           1673      1465    1365
# 2      2019-01-03           1673      1465    1365
# 3      2019-01-04           1673      1465    1365
# 4      2019-01-05           1673      1465    1365
# ...           ...            ...       ...     ...
# 181709 2019-12-27              0      1540    1389
# 181710 2019-12-28              0      1540    1389
# 181711 2019-12-29              0      1540    1389
# 181712 2019-12-30              0      1540    1389
# 181713 2019-12-31              0      1540    1389
#
# [181714 rows x 4 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181714 entries, 0 to 181713
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   day            181714 non-null  datetime64[ns]
#  1   high-gasoline  181714 non-null  int64
#  2   gasoline       181714 non-null  int64
#  3   diesel         181714 non-null  int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 5.5 MB

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    df1,
    x="day", hue='high-gasoline',
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())

# sns.histplot?
# ax.set_xticks([500, 1000, 2000, 5000, 10000])

plt.show()
# Out:
# c:\users\limwg\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 상표별 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 상표 종류
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 상표와 낮은 상표
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 상표와 낮은 상표

# %%
df.head(3)
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday

# %%
# 사용할 데이터
df[['기간','상표','고급휘발유','휘발유','경유']].head()
# Out:
#           기간     상표  고급휘발유   휘발유    경유
# 0 2019-01-01  SK에너지   1673  1465  1365
# 1 2019-01-02  SK에너지   1673  1465  1365
# 2 2019-01-03  SK에너지   1673  1465  1365
# 3 2019-01-04  SK에너지   1673  1465  1365
# 4 2019-01-05  SK에너지   1673  1465  1365

# %%
d1 = df.pivot_table(values='휘발유', columns=['상표'],index=['기간']) #   aggfunc='mean'
d1.head()
# Out:
# 상표                GS칼텍스  NH-OIL        S-OIL        SK에너지  알뜰(ex)  \
# 기간
# 2019-01-01  1485.786765  1399.0  1453.360000  1540.519802  1299.0
# 2019-01-02  1481.397059  1399.0  1451.440000  1536.188119  1319.0
# 2019-01-03  1474.551471  1399.0  1448.360000  1532.103960  1319.0
# 2019-01-04  1472.073529  1399.0  1444.608108  1530.242574  1319.0
# 2019-01-05  1469.133333  1399.0  1444.054054  1521.574257  1299.0
#
# 상표                알뜰주유소         자가상표       현대오일뱅크
# 기간
# 2019-01-01  1355.181818  1406.666667  1449.935897
# 2019-01-02  1354.000000  1406.666667  1446.320513
# 2019-01-03  1349.636364  1403.333333  1442.102564
# 2019-01-04  1349.454545  1391.333333  1440.038462
# 2019-01-05  1348.818182  1391.333333  1436.756410

# %%
# d1.rename(columns={"GS칼텍스": "A","NH-OIL": "B","S-OIL": "C","SK에너지": "D",
#                    "알뜰(ex)": "E","알뜰주유소": "F","자가상표": "G","현대오일뱅크": "H"}, inplace=True)
d1 = d1.rolling(7).mean()
d1
# Out:
# 상표                GS칼텍스  NH-OIL        S-OIL        SK에너지       알뜰(ex)  \
# 기간
# 2019-01-01          NaN     NaN          NaN          NaN          NaN
# 2019-01-02          NaN     NaN          NaN          NaN          NaN
# 2019-01-03          NaN     NaN          NaN          NaN          NaN
# 2019-01-04          NaN     NaN          NaN          NaN          NaN
# 2019-01-05          NaN     NaN          NaN          NaN          NaN
# ...                 ...     ...          ...          ...          ...
# 2019-12-27  1634.297495     NaN  1602.816466  1676.044530  1464.571429
# 2019-12-28  1634.772891     NaN  1603.402932  1676.415876  1464.571429
# 2019-12-29  1635.223156     NaN  1603.791353  1676.846661  1464.571429
# 2019-12-30  1635.712963     NaN  1601.381579  1677.129320  1464.571429
# 2019-12-31  1638.050327     NaN  1601.987744  1677.578518  1460.285714
#
# 상표                알뜰주유소         자가상표       현대오일뱅크
# 기간
# 2019-01-01          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN
# ...                 ...          ...          ...
# 2019-12-27  1529.025974  1555.952381  1579.583929
# 2019-12-28  1529.168831  1555.476190  1580.094643
# 2019-12-29  1529.311688  1555.000000  1580.775000
# 2019-12-30  1529.454545  1559.285714  1581.253571
# 2019-12-31  1530.194805  1564.523810  1581.546429
#
# [365 rows x 8 columns]

# %%
# 한글 깨짐 현상이 있어서 밑의 방식으로 해결
sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# 한글폰트 설정 확인을 합니다.
pd.Series([1, -1, 0, 5, -5]).plot(title="한글폰트")
# Out:
# <AxesSubplot:title={'center':'한글폰트'}>

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       359 non-null    float64
#  1   B       168 non-null    float64
#  2   C       359 non-null    float64
#  3   D       359 non-null    float64
#  4   E       359 non-null    float64
#  5   F       359 non-null    float64
#  6   G       359 non-null    float64
#  7   H       359 non-null    float64
# dtypes: float64(8)
# memory usage: 25.7 KB

# %%
# sns.set_style(style="whitegrid")

plt.figure(figsize=(20,10))
# sns.lineplot(data=d1,x='기간',y='상표', palette="tab10", linewidth=2.5)
sns.lineplot(data=d1,palette="tab10", linewidth=2.5,dashes=False)
# Out:
# <AxesSubplot:xlabel='기간'>

# %%
# d2 = df.pivot_table(values='경유', index='상표', columns=['셀프여부','기간'])
d2 = df.pivot_table(values='경유', columns=['상표'], index=['기간'])
d2.head(5)
# Out:
# 상표                GS칼텍스  NH-OIL        S-OIL        SK에너지  알뜰(ex)  \
# 기간
# 2019-01-01  1374.816176  1299.0  1339.706667  1419.346535  1199.0
# 2019-01-02  1370.536765  1299.0  1336.320000  1420.886139  1219.0
# 2019-01-03  1364.786765  1299.0  1333.360000  1416.881188  1219.0
# 2019-01-04  1362.941176  1299.0  1329.918919  1416.034653  1219.0
# 2019-01-05  1360.525926  1299.0  1329.594595  1407.653465  1199.0
#
# 상표                알뜰주유소         자가상표       현대오일뱅크
# 기간
# 2019-01-01  1253.181818  1306.666667  1339.512821
# 2019-01-02  1252.181818  1306.666667  1335.858974
# 2019-01-03  1247.636364  1303.333333  1332.307692
# 2019-01-04  1247.636364  1287.666667  1330.064103
# 2019-01-05  1248.909091  1287.666667  1327.243590

# %%
# d2.rename(columns={"GS칼텍스": "A","NH-OIL": "B","S-OIL": "C","SK에너지": "D",
#                    "알뜰(ex)": "E","알뜰주유소": "F","자가상표": "G","현대오일뱅크": "H"}, inplace=True)
d2 = d2.rolling(7).mean()
d2
# Out:
# 상표                GS칼텍스  NH-OIL        S-OIL        SK에너지       알뜰(ex)  \
# 기간
# 2019-01-01          NaN     NaN          NaN          NaN          NaN
# 2019-01-02          NaN     NaN          NaN          NaN          NaN
# 2019-01-03          NaN     NaN          NaN          NaN          NaN
# 2019-01-04          NaN     NaN          NaN          NaN          NaN
# 2019-01-05          NaN     NaN          NaN          NaN          NaN
# ...                 ...     ...          ...          ...          ...
# 2019-12-27  1483.154303     NaN  1436.863634  1519.352900  1322.000000
# 2019-12-28  1483.800163     NaN  1437.203860  1519.698641  1319.142857
# 2019-12-29  1484.356310     NaN  1437.453008  1520.262254  1316.285714
# 2019-12-30  1484.955065     NaN  1437.755639  1520.580818  1316.571429
# 2019-12-31  1485.423055     NaN  1438.201203  1520.984179  1313.714286
#
# 상표                알뜰주유소         자가상표       현대오일뱅크
# 기간
# 2019-01-01          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN
# ...                 ...          ...          ...
# 2019-12-27  1360.779221  1388.809524  1415.673214
# 2019-12-28  1360.519481  1387.714286  1416.191071
# 2019-12-29  1360.415584  1386.619048  1416.589286
# 2019-12-30  1360.311688  1385.523810  1416.964286
# 2019-12-31  1360.350649  1386.000000  1417.366071
#
# [365 rows x 8 columns]

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GS칼텍스   359 non-null    float64
#  1   NH-OIL  168 non-null    float64
#  2   S-OIL   359 non-null    float64
#  3   SK에너지   359 non-null    float64
#  4   알뜰(ex)  359 non-null    float64
#  5   알뜰주유소   359 non-null    float64
#  6   자가상표    359 non-null    float64
#  7   현대오일뱅크  359 non-null    float64
# dtypes: float64(8)
# memory usage: 25.7 KB

# %%
# sns.set_style(style="whitegrid")

plt.figure(figsize=(20,10))
# sns.lineplot(data=d1,x='기간',y='상표', palette="tab10", linewidth=2.5)
sns.lineplot(data=d2,palette="tab10", linewidth=2.5,dashes=False)
# Out:
# <AxesSubplot:xlabel='기간'>

# %%
# d3 = df.pivot_table(values='고급휘발유', index='상표', columns=['셀프여부','기간'])
d3 = df.pivot_table(values='고급휘발유', index=['기간'], columns=['상표'])
d3.head()
# Out:
# 상표               GS칼텍스  NH-OIL       S-OIL       SK에너지  알뜰(ex)  알뜰주유소  자가상표  \
# 기간
# 2019-01-01  946.808824     0.0  286.266667  862.613861     0.0    0.0   0.0
# 2019-01-02  958.367647     0.0  286.266667  868.217822     0.0    0.0   0.0
# 2019-01-03  954.455882     0.0  285.760000  867.143564     0.0    0.0   0.0
# 2019-01-04  951.161765     0.0  289.216216  867.396040     0.0    0.0   0.0
# 2019-01-05  957.925926     0.0  289.351351  857.391089     0.0    0.0   0.0
#
# 상표              현대오일뱅크
# 기간
# 2019-01-01  320.910256
# 2019-01-02  320.807692
# 2019-01-03  317.269231
# 2019-01-04  316.884615
# 2019-01-05  316.500000

# %%
# d2.rename(columns={"GS칼텍스": "A","NH-OIL": "B","S-OIL": "C","SK에너지": "D",
#                    "알뜰(ex)": "E","알뜰주유소": "F","자가상표": "G","현대오일뱅크": "H"}, inplace=True)
d3 = d3.rolling(7).mean()
d3
# Out:
# 상표                GS칼텍스  NH-OIL       S-OIL       SK에너지  알뜰(ex)  알뜰주유소  자가상표  \
# 기간
# 2019-01-01          NaN     NaN         NaN         NaN     NaN    NaN   NaN
# 2019-01-02          NaN     NaN         NaN         NaN     NaN    NaN   NaN
# 2019-01-03          NaN     NaN         NaN         NaN     NaN    NaN   NaN
# 2019-01-04          NaN     NaN         NaN         NaN     NaN    NaN   NaN
# 2019-01-05          NaN     NaN         NaN         NaN     NaN    NaN   NaN
# ...                 ...     ...         ...         ...     ...    ...   ...
# 2019-12-27  1074.383691     NaN  392.226917  945.056528     0.0    0.0   0.0
# 2019-12-28  1073.777070     NaN  392.208120  944.260336     0.0    0.0   0.0
# 2019-12-29  1073.191612     NaN  391.537594  945.032254     0.0    0.0   0.0
# 2019-12-30  1072.588477     NaN  391.537594  945.085730     0.0    0.0   0.0
# 2019-12-31  1074.139986     NaN  392.359248  945.293522     0.0    0.0   0.0
#
# 상표              현대오일뱅크
# 기간
# 2019-01-01         NaN
# 2019-01-02         NaN
# 2019-01-03         NaN
# 2019-01-04         NaN
# 2019-01-05         NaN
# ...                ...
# 2019-12-27  661.241071
# 2019-12-28  661.285714
# 2019-12-29  661.330357
# 2019-12-30  661.375000
# 2019-12-31  661.437500
#
# [365 rows x 8 columns]

# %%
# sns.set_style(style="whitegrid")

plt.figure(figsize=(20,10))
# sns.lineplot(data=d1,x='기간',y='상표', palette="tab10", linewidth=2.5)
sns.lineplot(data=d3,palette="tab10", linewidth=2.5,dashes=False)
# Out:
# <AxesSubplot:xlabel='기간'>

# %% [markdown]
# ## 지역별(구) 평균 가격의 변화 - 휘발유, 경유, 고급 휘발유
# y축:평균 가격, x축:날짜 그래프 개수: 지역(구)
# hue : 셀프여부
# -> 결론 : 휘발유, 경유, 고급 휘발유의 평균 가격이 가장 높은 지역과 낮은 지역
# 	휘발유, 경유, 고급 휘발유의 가격 변동률이 가장 높은 지역와 낮은 지역

# %%
df.head()
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday
# 3   1673  1465  1365     0  서울특별시  강남구  2019  1  4     Friday
# 4   1673  1465  1365     0  서울특별시  강남구  2019  1  5   Saturday

# %%
# 사용할 데이터
df[['기간','구','고급휘발유','휘발유','경유']].head()
# Out:
#           기간    구  고급휘발유   휘발유    경유
# 0 2019-01-01  강남구   1673  1465  1365
# 1 2019-01-02  강남구   1673  1465  1365
# 2 2019-01-03  강남구   1673  1465  1365
# 3 2019-01-04  강남구   1673  1465  1365
# 4 2019-01-05  강남구   1673  1465  1365

# %%
d1 = df.pivot_table(values='휘발유', columns=['구'],index=['기간']) #   aggfunc='mean'
d1.head()
# Out:
# 구                   강남구          강동구          강북구          강서구          관악구  \
# 기간
# 2019-01-01  1646.512195  1529.470588  1381.153846  1416.028571  1456.500000
# 2019-01-02  1645.609756  1525.941176  1379.153846  1410.685714  1452.055556
# 2019-01-03  1641.365854  1516.058824  1376.307692  1404.657143  1448.722222
# 2019-01-04  1637.487805  1513.117647  1375.846154  1401.294118  1445.444444
# 2019-01-05  1634.609756  1512.529412  1367.307692  1397.705882  1437.352941
#
# 구                   광진구          구로구          금천구          노원구          도봉구  \
# 기간
# 2019-01-01  1407.222222  1433.523810  1390.076923  1434.933333  1399.421053
# 2019-01-02  1409.222222  1429.571429  1380.615385  1433.066667  1397.789474
# 2019-01-03  1404.888889  1429.476190  1380.615385  1424.333333  1395.526316
# 2019-01-04  1405.444444  1427.285714  1380.615385  1420.266667  1393.526316
# 2019-01-05  1399.222222  1427.285714  1379.769231  1420.266667  1387.473684
#
# 구           ...          성동구          성북구          송파구      양천구        영등포구  \
# 기간          ...
# 2019-01-01  ...  1514.117647  1426.565217  1445.225806  1433.44  1508.09375
# 2019-01-02  ...  1508.588235  1425.608696  1431.258065  1430.64  1505.09375
# 2019-01-03  ...  1503.823529  1422.782609  1422.709677  1423.40  1499.93750
# 2019-01-04  ...  1500.705882  1420.086957  1421.387097  1422.60  1496.12500
# 2019-01-05  ...  1496.588235  1420.260870  1420.000000  1421.24  1498.68750
#
# 구                   용산구          은평구          종로구           중구        중랑구
# 기간
# 2019-01-01  1800.466667  1389.764706  1772.888889  1853.666667  1387.5625
# 2019-01-02  1794.466667  1384.941176  1766.222222  1848.833333  1383.8125
# 2019-01-03  1787.133333  1379.647059  1764.000000  1843.833333  1379.5625
# 2019-01-04  1787.133333  1375.470588  1764.000000  1844.583333  1377.0625
# 2019-01-05  1780.266667  1374.000000  1764.000000  1844.583333  1378.5000
#
# [5 rows x 25 columns]

# %%
# d2.rename(columns={"GS칼텍스": "A","NH-OIL": "B","S-OIL": "C","SK에너지": "D",
#                    "알뜰(ex)": "E","알뜰주유소": "F","자가상표": "G","현대오일뱅크": "H"}, inplace=True)
d1 = d1.rolling(7).mean()
d1
# Out:
# 구                   강남구          강동구          강북구          강서구          관악구  \
# 기간
# 2019-01-01          NaN          NaN          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2019-12-27  1773.256410  1638.428571  1514.263736  1567.382990  1595.544643
# 2019-12-28  1773.538462  1638.875000  1514.813187  1568.681309  1595.633929
# 2019-12-29  1773.783883  1639.142857  1515.582418  1569.810924  1595.723214
# 2019-12-30  1774.029304  1639.410714  1516.461538  1570.957983  1595.812500
# 2019-12-31  1774.311355  1639.678571  1517.296703  1571.882353  1595.991071
#
# 구                   광진구          구로구          금천구          노원구          도봉구  \
# 기간
# 2019-01-01          NaN          NaN          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2019-12-27  1562.949580  1602.551020  1563.516484  1603.914286  1537.571429
# 2019-12-28  1563.378151  1603.136054  1563.846154  1604.657143  1538.444444
# 2019-12-29  1563.815126  1603.721088  1564.175824  1605.400000  1540.174603
# 2019-12-30  1564.310924  1604.306122  1564.615385  1606.142857  1541.603175
# 2019-12-31  1564.865546  1604.823129  1565.054945  1606.885714  1542.285714
#
# 구           ...          성동구          성북구          송파구          양천구  \
# 기간          ...
# 2019-01-01  ...          NaN          NaN          NaN          NaN
# 2019-01-02  ...          NaN          NaN          NaN          NaN
# 2019-01-03  ...          NaN          NaN          NaN          NaN
# 2019-01-04  ...          NaN          NaN          NaN          NaN
# 2019-01-05  ...          NaN          NaN          NaN          NaN
# ...         ...          ...          ...          ...          ...
# 2019-12-27  ...  1652.798319  1569.291925  1571.766234  1577.678681
# 2019-12-28  ...  1653.033613  1570.062112  1572.138528  1577.931429
# 2019-12-29  ...  1653.235294  1570.447205  1572.424242  1578.300220
# 2019-12-30  ...  1653.436975  1561.217391  1572.969697  1578.580440
# 2019-12-31  ...  1653.554622  1561.989836  1573.891775  1579.052967
#
# 구                  영등포구          용산구          은평구          종로구           중구  \
# 기간
# 2019-01-01          NaN          NaN          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2019-12-27  1644.450893  1915.273469  1551.806723  1901.539683  2065.597403
# 2019-12-28  1644.584821  1918.546939  1552.504202  1901.269841  2065.129870
# 2019-12-29  1644.852679  1921.820408  1553.126050  1901.000000  2064.662338
# 2019-12-30  1644.745536  1925.297959  1554.428571  1900.730159  2064.194805
# 2019-12-31  1644.607143  1944.538776  1555.941176  1900.079365  2064.051948
#
# 구                   중랑구
# 기간
# 2019-01-01          NaN
# 2019-01-02          NaN
# 2019-01-03          NaN
# 2019-01-04          NaN
# 2019-01-05          NaN
# ...                 ...
# 2019-12-27  1543.866071
# 2019-12-28  1544.508929
# 2019-12-29  1545.116071
# 2019-12-30  1545.366071
# 2019-12-31  1545.616071
#
# [365 rows x 25 columns]

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강남구     359 non-null    float64
#  1   강동구     359 non-null    float64
#  2   강북구     359 non-null    float64
#  3   강서구     359 non-null    float64
#  4   관악구     359 non-null    float64
#  5   광진구     359 non-null    float64
#  6   구로구     359 non-null    float64
#  7   금천구     359 non-null    float64
#  8   노원구     359 non-null    float64
#  9   도봉구     359 non-null    float64
#  10  동대문구    359 non-null    float64
#  11  동작구     359 non-null    float64
#  12  마포구     359 non-null    float64
#  13  서대문구    359 non-null    float64
#  14  서초구     359 non-null    float64
#  15  성동구     359 non-null    float64
#  16  성북구     359 non-null    float64
#  17  송파구     359 non-null    float64
#  18  양천구     359 non-null    float64
#  19  영등포구    359 non-null    float64
#  20  용산구     359 non-null    float64
#  21  은평구     359 non-null    float64
#  22  종로구     359 non-null    float64
#  23  중구      359 non-null    float64
#  24  중랑구     359 non-null    float64
# dtypes: float64(25)
# memory usage: 74.1 KB

# %%
# sns.set_style(style="whitegrid")

plt.figure(figsize=(20,10))
# sns.lineplot(data=d1,x='기간',y='상표', palette="tab10", linewidth=2.5)
sns.lineplot(data=d1,palette="tab10", linewidth=2.5,dashes=False)
# Out:
# <AxesSubplot:xlabel='기간'>

# %%
d2 = df.pivot_table(values='경유', columns=['구'],index=['기간']) #   aggfunc='mean'
d2.head()
# Out:
# 구                   강남구          강동구          강북구          강서구          관악구  \
# 기간
# 2019-01-01  1519.365854  1405.647059  1265.153846  1309.142857  1341.111111
# 2019-01-02  1518.243902  1404.470588  1260.615385  1304.485714  1334.833333
# 2019-01-03  1513.609756  1394.294118  1258.615385  1299.800000  1332.055556
# 2019-01-04  1510.585366  1393.705882  1253.307692  1295.588235  1328.722222
# 2019-01-05  1508.512195  1393.117647  1251.076923  1292.705882  1319.647059
#
# 구                   광진구          구로구          금천구          노원구          도봉구  \
# 기간
# 2019-01-01  1308.055556  1319.095238  1291.538462  1331.533333  1296.263158
# 2019-01-02  1307.888889  1315.142857  1281.230769  1324.800000  1293.578947
# 2019-01-03  1305.333333  1315.047619  1281.923077  1320.933333  1292.736842
# 2019-01-04  1303.833333  1312.904762  1281.230769  1318.800000  1291.526316
# 2019-01-05  1301.111111  1312.904762  1284.307692  1318.800000  1287.368421
#
# 구           ...          성동구          성북구          송파구      양천구        영등포구  \
# 기간          ...
# 2019-01-01  ...  1414.411765  1321.652174  1332.838710  1319.00  1398.56250
# 2019-01-02  ...  1402.470588  1321.173913  1323.225806  1316.32  1395.56250
# 2019-01-03  ...  1397.705882  1318.391304  1317.129032  1308.84  1390.56250
# 2019-01-04  ...  1398.058824  1316.652174  1316.032258  1308.04  1390.09375
# 2019-01-05  ...  1393.941176  1316.652174  1313.741935  1307.48  1390.09375
#
# 구                   용산구          은평구          종로구           중구        중랑구
# 기간
# 2019-01-01  1680.666667  1280.588235  1642.888889  1743.333333  1288.3125
# 2019-01-02  1674.000000  1275.529412  1636.222222  1733.916667  1286.4375
# 2019-01-03  1666.000000  1270.470588  1634.000000  1730.333333  1282.5625
# 2019-01-04  1666.000000  1266.294118  1634.000000  1729.166667  1283.8125
# 2019-01-05  1661.466667  1264.823529  1634.000000  1730.250000  1280.6875
#
# [5 rows x 25 columns]

# %%
# d2.rename(columns={"GS칼텍스": "A","NH-OIL": "B","S-OIL": "C","SK에너지": "D",
#                    "알뜰(ex)": "E","알뜰주유소": "F","자가상표": "G","현대오일뱅크": "H"}, inplace=True)
d2 = d2.rolling(7).mean()
d2
# Out:
# 구                   강남구          강동구          강북구          강서구          관악구  \
# 기간
# 2019-01-01          NaN          NaN          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2019-12-27  1620.043956  1486.500000  1364.692308  1401.747772  1443.535714
# 2019-12-28  1621.117216  1487.214286  1365.131868  1402.600713  1443.446429
# 2019-12-29  1621.787546  1487.839286  1365.681319  1403.462185  1443.535714
# 2019-12-30  1622.465201  1488.464286  1366.450549  1404.411765  1443.625000
# 2019-12-31  1622.589744  1489.089286  1367.219780  1405.214286  1443.625000
#
# 구                   광진구          구로구          금천구          노원구          도봉구  \
# 기간
# 2019-01-01          NaN          NaN          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2019-12-27  1392.193277  1424.340136  1398.384615  1448.323810  1383.857143
# 2019-12-28  1392.277311  1424.884354  1398.384615  1448.895238  1384.063492
# 2019-12-29  1392.537815  1425.428571  1398.384615  1449.466667  1384.269841
# 2019-12-30  1392.798319  1425.904762  1398.384615  1450.038095  1384.476190
# 2019-12-31  1393.067227  1426.244898  1398.384615  1450.609524  1384.833333
#
# 구           ...          성동구          성북구          송파구          양천구  \
# 기간          ...
# 2019-01-01  ...          NaN          NaN          NaN          NaN
# 2019-01-02  ...          NaN          NaN          NaN          NaN
# 2019-01-03  ...          NaN          NaN          NaN          NaN
# 2019-01-04  ...          NaN          NaN          NaN          NaN
# 2019-01-05  ...          NaN          NaN          NaN          NaN
# ...         ...          ...          ...          ...          ...
# 2019-12-27  ...  1484.680672  1405.496894  1419.584416  1410.615604
# 2019-12-28  ...  1484.957983  1406.055901  1419.991342  1410.687033
# 2019-12-29  ...  1485.126050  1406.552795  1420.398268  1411.124615
# 2019-12-30  ...  1485.327731  1406.987578  1420.753247  1411.267473
# 2019-12-31  ...  1485.529412  1407.885375  1421.151515  1411.635604
#
# 구                  영등포구          용산구          은평구          종로구           중구  \
# 기간
# 2019-01-01          NaN          NaN          NaN          NaN          NaN
# 2019-01-02          NaN          NaN          NaN          NaN          NaN
# 2019-01-03          NaN          NaN          NaN          NaN          NaN
# 2019-01-04          NaN          NaN          NaN          NaN          NaN
# 2019-01-05          NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2019-12-27  1486.075893  1817.261224  1396.815126  1740.793651  1887.194805
# 2019-12-28  1486.299107  1820.484354  1397.176471  1741.000000  1887.000000
# 2019-12-29  1486.830357  1823.707483  1397.386555  1741.206349  1886.805195
# 2019-12-30  1487.004464  1827.134694  1397.529412  1741.412698  1886.584416
# 2019-12-31  1487.174107  1830.212245  1397.991597  1741.238095  1886.259740
#
# 구                   중랑구
# 기간
# 2019-01-01          NaN
# 2019-01-02          NaN
# 2019-01-03          NaN
# 2019-01-04          NaN
# 2019-01-05          NaN
# ...                 ...
# 2019-12-27  1373.651786
# 2019-12-28  1374.535714
# 2019-12-29  1375.419643
# 2019-12-30  1376.125000
# 2019-12-31  1376.732143
#
# [365 rows x 25 columns]

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강남구     359 non-null    float64
#  1   강동구     359 non-null    float64
#  2   강북구     359 non-null    float64
#  3   강서구     359 non-null    float64
#  4   관악구     359 non-null    float64
#  5   광진구     359 non-null    float64
#  6   구로구     359 non-null    float64
#  7   금천구     359 non-null    float64
#  8   노원구     359 non-null    float64
#  9   도봉구     359 non-null    float64
#  10  동대문구    359 non-null    float64
#  11  동작구     359 non-null    float64
#  12  마포구     359 non-null    float64
#  13  서대문구    359 non-null    float64
#  14  서초구     359 non-null    float64
#  15  성동구     359 non-null    float64
#  16  성북구     359 non-null    float64
#  17  송파구     359 non-null    float64
#  18  양천구     359 non-null    float64
#  19  영등포구    359 non-null    float64
#  20  용산구     359 non-null    float64
#  21  은평구     359 non-null    float64
#  22  종로구     359 non-null    float64
#  23  중구      359 non-null    float64
#  24  중랑구     359 non-null    float64
# dtypes: float64(25)
# memory usage: 74.1 KB

# %%
# sns.set_style(style="whitegrid")

plt.figure(figsize=(20,10))
# sns.lineplot(data=d1,x='기간',y='상표', palette="tab10", linewidth=2.5)
sns.lineplot(data=d2,palette="tab10", linewidth=2.5,dashes=False)
# Out:
# <AxesSubplot:xlabel='기간'>

# %%
d3 = df.pivot_table(values='고급휘발유', columns=['구'],index=['기간']) #   aggfunc='mean'
d3.head()
# Out:
# 구                   강남구         강동구         강북구         강서구         관악구  \
# 기간
# 2019-01-01  1566.243902  744.823529  396.384615  487.942857  290.277778
# 2019-01-02  1564.609756  743.058824  396.384615  539.314286  289.722222
# 2019-01-03  1560.951220  735.823529  396.384615  533.028571  289.722222
# 2019-01-04  1557.317073  732.882353  394.846154  548.705882  289.722222
# 2019-01-05  1508.268293  735.823529  394.846154  547.294118  306.764706
#
# 구                  광진구        구로구         금천구         노원구         도봉구  ...  \
# 기간                                                                     ...
# 2019-01-01  460.611111  79.428571  120.461538  562.266667  363.105263  ...
# 2019-01-02  460.166667  79.428571  120.461538  555.400000  363.105263  ...
# 2019-01-03  459.555556  79.428571  120.461538  555.400000  362.736842  ...
# 2019-01-04  459.555556  79.428571  120.461538  555.400000  362.736842  ...
# 2019-01-05  459.555556  79.428571  120.461538  555.400000  362.736842  ...
#
# 구                  성동구         성북구         송파구     양천구      영등포구          용산구  \
# 기간
# 2019-01-01  759.764706  462.391304  693.806452  559.48  299.9375  1929.600000
# 2019-01-02  756.823529  462.391304  692.161290  555.48  299.9375  1924.266667
# 2019-01-03  755.352941  462.391304  689.258065  554.68  298.9375  1922.266667
# 2019-01-04  755.352941  461.478261  689.258065  554.68  298.9375  1922.266667
# 2019-01-05  755.352941  461.478261  687.806452  554.68  298.9375  1918.533333
#
# 구                  은평구          종로구           중구      중랑구
# 기간
# 2019-01-01  510.000000  1386.000000  1670.416667  214.125
# 2019-01-02  508.823529  1383.777778  1662.750000  214.125
# 2019-01-03  507.058824  1381.555556  1656.416667  214.125
# 2019-01-04  505.470588  1381.555556  1658.916667  214.125
# 2019-01-05  503.882353  1381.555556  1663.750000  214.125
#
# [5 rows x 25 columns]

# %%
# d2.rename(columns={"GS칼텍스": "A","NH-OIL": "B","S-OIL": "C","SK에너지": "D",
#                    "알뜰(ex)": "E","알뜰주유소": "F","자가상표": "G","현대오일뱅크": "H"}, inplace=True)
d3 = d3.rolling(7).mean()
d3
# Out:
# 구                   강남구         강동구         강북구         강서구       관악구  \
# 기간
# 2019-01-01          NaN         NaN         NaN         NaN       NaN
# 2019-01-02          NaN         NaN         NaN         NaN       NaN
# 2019-01-03          NaN         NaN         NaN         NaN       NaN
# 2019-01-04          NaN         NaN         NaN         NaN       NaN
# 2019-01-05          NaN         NaN         NaN         NaN       NaN
# ...                 ...         ...         ...         ...       ...
# 2019-12-27  1683.780220  843.883929  559.692308  615.102368  458.3125
# 2019-12-28  1684.025641  844.062500  559.692308  615.375477  458.3125
# 2019-12-29  1684.271062  844.062500  559.692308  613.210084  458.3125
# 2019-12-30  1684.516484  844.062500  559.802198  613.525210  458.3125
# 2019-12-31  1684.992674  844.062500  559.912088  613.882353  458.3125
#
# 구                  광진구        구로구         금천구         노원구         도봉구  ...  \
# 기간                                                                     ...
# 2019-01-01         NaN        NaN         NaN         NaN         NaN  ...
# 2019-01-02         NaN        NaN         NaN         NaN         NaN  ...
# 2019-01-03         NaN        NaN         NaN         NaN         NaN  ...
# 2019-01-04         NaN        NaN         NaN         NaN         NaN  ...
# 2019-01-05         NaN        NaN         NaN         NaN         NaN  ...
# ...                ...        ...         ...         ...         ...  ...
# 2019-12-27  842.016807  247.52381  130.725275  592.980952  405.777778  ...
# 2019-12-28  842.100840  247.52381  130.835165  592.980952  405.777778  ...
# 2019-12-29  842.184874  247.52381  130.945055  592.980952  405.777778  ...
# 2019-12-30  842.268908  247.52381  131.054945  592.980952  405.857143  ...
# 2019-12-31  842.352941  247.52381  131.164835  592.847619  405.936508  ...
#
# 구                  성동구         성북구         송파구         양천구        영등포구  \
# 기간
# 2019-01-01         NaN         NaN         NaN         NaN         NaN
# 2019-01-02         NaN         NaN         NaN         NaN         NaN
# 2019-01-03         NaN         NaN         NaN         NaN         NaN
# 2019-01-04         NaN         NaN         NaN         NaN         NaN
# 2019-01-05         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2019-12-27  803.000000  626.086957  795.255411  624.906813  533.866071
# 2019-12-28  803.000000  625.440994  795.177489  625.071648  533.910714
# 2019-12-29  803.000000  625.689441  795.350649  628.854066  533.955357
# 2019-12-30  803.000000  625.937888  795.523810  629.018901  534.000000
# 2019-12-31  803.084034  630.328063  795.696970  629.183736  534.000000
#
# 구                   용산구         은평구          종로구           중구         중랑구
# 기간
# 2019-01-01          NaN         NaN          NaN          NaN         NaN
# 2019-01-02          NaN         NaN          NaN          NaN         NaN
# 2019-01-03          NaN         NaN          NaN          NaN         NaN
# 2019-01-04          NaN         NaN          NaN          NaN         NaN
# 2019-01-05          NaN         NaN          NaN          NaN         NaN
# ...                 ...         ...          ...          ...         ...
# 2019-12-27  2172.028571  610.764706  1687.539683  1939.506494  230.750000
# 2019-12-28  2175.314286  610.932773  1687.063492  1939.220779  230.839286
# 2019-12-29  2178.600000  611.016807  1686.587302  1938.935065  230.928571
# 2019-12-30  2181.739456  611.016807  1686.111111  1938.649351  231.017857
# 2019-12-31  2203.689796  611.016807  1686.111111  1938.701299  231.107143
#
# [365 rows x 25 columns]

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강남구     359 non-null    float64
#  1   강동구     359 non-null    float64
#  2   강북구     359 non-null    float64
#  3   강서구     359 non-null    float64
#  4   관악구     359 non-null    float64
#  5   광진구     359 non-null    float64
#  6   구로구     359 non-null    float64
#  7   금천구     359 non-null    float64
#  8   노원구     359 non-null    float64
#  9   도봉구     359 non-null    float64
#  10  동대문구    359 non-null    float64
#  11  동작구     359 non-null    float64
#  12  마포구     359 non-null    float64
#  13  서대문구    359 non-null    float64
#  14  서초구     359 non-null    float64
#  15  성동구     359 non-null    float64
#  16  성북구     359 non-null    float64
#  17  송파구     359 non-null    float64
#  18  양천구     359 non-null    float64
#  19  영등포구    359 non-null    float64
#  20  용산구     359 non-null    float64
#  21  은평구     359 non-null    float64
#  22  종로구     359 non-null    float64
#  23  중구      359 non-null    float64
#  24  중랑구     359 non-null    float64
# dtypes: float64(25)
# memory usage: 74.1 KB

# %%
# sns.set_style(style="whitegrid")

plt.figure(figsize=(20,10))
# sns.lineplot(data=d1,x='기간',y='상표', palette="tab10", linewidth=2.5)
sns.lineplot(data=d3,palette="tab10", linewidth=2.5,dashes=False)
# Out:
# <AxesSubplot:xlabel='기간'>
